# %% [markdown]
# # Softmax Regression Example

# %% [markdown]
# ### 生成数据集， 看明白即可无需填写代码
# #### '<font color="blue">+</font>' 从高斯分布采样 (X, Y) ~ N(3, 6, 1, 1, 0).<br>
# #### '<font color="green">o</font>' 从高斯分布采样  (X, Y) ~ N(6, 3, 1, 1, 0)<br>
# #### '<font color="red">*</font>' 从高斯分布采样  (X, Y) ~ N(7, 7, 1, 1, 0)<br>

# %%
import platform
import tensorflow as tf
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML
import matplotlib.cm as cm
import numpy as np
# %matplotlib inline

platform_system = platform.system()
platform_machine = platform.machine()
if platform_system == "Darwin" and platform_machine == "arm64":
    is_macos_m1 = True
    
dot_num = 100
x_p = np.random.normal(3., 1, dot_num)
y_p = np.random.normal(6., 1, dot_num)
y = np.ones(dot_num)
C1 = np.array([x_p, y_p, y]).T

x_n = np.random.normal(6., 1, dot_num)
y_n = np.random.normal(3., 1, dot_num)
y = np.zeros(dot_num)
C2 = np.array([x_n, y_n, y]).T

x_b = np.random.normal(7., 1, dot_num)
y_b = np.random.normal(7., 1, dot_num)
y = np.ones(dot_num)*2
C3 = np.array([x_b, y_b, y]).T

plt.scatter(C1[:, 0], C1[:, 1], c='b', marker='+')
plt.scatter(C2[:, 0], C2[:, 1], c='g', marker='o')
plt.scatter(C3[:, 0], C3[:, 1], c='r', marker='*')

data_set = np.concatenate((C1, C2, C3), axis=0)
np.random.shuffle(data_set)

# %% [markdown]
# ## 建立模型
# 建立模型类，定义loss函数，定义一步梯度下降过程函数
#
# 填空一：在`__init__`构造函数中建立模型所需的参数
#
# 填空二：实现softmax的交叉熵损失函数(不使用tf内置的loss 函数)

# %%
epsilon = 1e-12
class SoftmaxRegression():
    def __init__(self):
        '''============================='''
        #todo 填空一，构建模型所需的参数 self.W, self.b 可以参考logistic-regression-exercise
        '''============================='''
        self.W = tf.Variable(shape=[2, 3], dtype=tf.float32, 
            initial_value=tf.random.uniform(shape=[2, 3], minval=-0.1, maxval=0.1))
        self.b = tf.Variable(shape=[3], dtype=tf.float32, initial_value=tf.zeros(shape=[3]))
        
        self.trainable_variables = [self.W, self.b]
    @tf.function
    def __call__(self, inp):
        logits = tf.matmul(inp, self.W) + self.b # shape(N, 3)
        pred = tf.nn.softmax(logits)
        return pred    
    
@tf.function
def compute_loss(pred, label):
    label = tf.one_hot(tf.cast(label, dtype=tf.int32), dtype=tf.float32, depth=3)
    '''============================='''
    #输入label shape(N, 3), pred shape(N, 3)
    #输出 losses shape(N,) 每一个样本一个loss
    #todo 填空二，实现softmax的交叉熵损失函数(不使用tf内置的loss 函数)
    '''============================='''
    losses = -tf.reduce_sum(label * tf.math.log(pred + epsilon), axis=1)

    loss = tf.reduce_mean(losses)
    
    accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(label,axis=1), tf.argmax(pred, axis=1)), dtype=tf.float32))
    return loss, accuracy

@tf.function
def train_one_step(model, optimizer, x, y):
    with tf.GradientTape() as tape:
        pred = model(x)
        loss, accuracy = compute_loss(pred, y)
        
    grads = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    return loss, accuracy

# %% [markdown]
# ### 实例化一个模型，进行训练

# %%
model = SoftmaxRegression()
if is_macos_m1:
    opt = tf.keras.optimizers.legacy.SGD(learning_rate=0.01)
else:
    opt = tf.keras.optimizers.SGD(learning_rate=0.01)
x1, x2, y = list(zip(*data_set))
x = list(zip(x1, x2))
x = tf.constant(x, dtype=tf.float32)
y = tf.constant(y, dtype=tf.float32)
for i in range(6000):
    loss, accuracy = train_one_step(model, opt, x, y)
    if i%50==49:
        print(f'loss: {loss.numpy():.4}\t accuracy: {accuracy.numpy():.4}')
# Out:
# loss: 0.7549	 accuracy: 0.8033
# loss: 0.6239	 accuracy: 0.8867
# loss: 0.5495	 accuracy: 0.8933
# loss: 0.5003	 accuracy: 0.89
# loss: 0.4648	 accuracy: 0.8967
# loss: 0.4376	 accuracy: 0.9033
# loss: 0.4161	 accuracy: 0.9133
# loss: 0.3985	 accuracy: 0.9133
# loss: 0.3837	 accuracy: 0.9133
# loss: 0.3712	 accuracy: 0.9133
# loss: 0.3603	 accuracy: 0.9133
# loss: 0.3509	 accuracy: 0.9133
# loss: 0.3425	 accuracy: 0.9133
# loss: 0.335	 accuracy: 0.9133
# loss: 0.3283	 accuracy: 0.9133
# loss: 0.3223	 accuracy: 0.9133
# loss: 0.3168	 accuracy: 0.9133
# loss: 0.3118	 accuracy: 0.9133
# loss: 0.3072	 accuracy: 0.9133
# loss: 0.3029	 accuracy: 0.9167
# loss: 0.299	 accuracy: 0.9167
# loss: 0.2953	 accuracy: 0.9167
# loss: 0.2919	 accuracy: 0.9167
# loss: 0.2888	 accuracy: 0.9167
# loss: 0.2858	 accuracy: 0.9167
# loss: 0.283	 accuracy: 0.92
# loss: 0.2803	 accuracy: 0.92
# loss: 0.2778	 accuracy: 0.92
# loss: 0.2755	 accuracy: 0.92
# loss: 0.2732	 accuracy: 0.92
# loss: 0.2711	 accuracy: 0.92
# loss: 0.2691	 accuracy: 0.92
# loss: 0.2672	 accuracy: 0.92
# loss: 0.2653	 accuracy: 0.92
# loss: 0.2636	 accuracy: 0.92
# loss: 0.2619	 accuracy: 0.92
# loss: 0.2603	 accuracy: 0.92
# loss: 0.2587	 accuracy: 0.92
# loss: 0.2572	 accuracy: 0.92
# loss: 0.2558	 accuracy: 0.92
# loss: 0.2544	 accuracy: 0.92
# loss: 0.2531	 accuracy: 0.92
# loss: 0.2518	 accuracy: 0.92
# loss: 0.2505	 accuracy: 0.92
# loss: 0.2493	 accuracy: 0.92
# loss: 0.2482	 accuracy: 0.92
# loss: 0.247	 accuracy: 0.92
# loss: 0.246	 accuracy: 0.92
# loss: 0.2449	 accuracy: 0.92
# loss: 0.2439	 accuracy: 0.92
# loss: 0.2429	 accuracy: 0.92
# loss: 0.2419	 accuracy: 0.92
# loss: 0.241	 accuracy: 0.9233
# loss: 0.24	 accuracy: 0.9233
# loss: 0.2391	 accuracy: 0.9233
# loss: 0.2383	 accuracy: 0.9233
# loss: 0.2374	 accuracy: 0.9233
# loss: 0.2366	 accuracy: 0.9233
# loss: 0.2358	 accuracy: 0.9233
# loss: 0.235	 accuracy: 0.9233
# loss: 0.2342	 accuracy: 0.9233
# loss: 0.2334	 accuracy: 0.9233
# loss: 0.2327	 accuracy: 0.9233
# loss: 0.232	 accuracy: 0.9233
# loss: 0.2313	 accuracy: 0.9233
# loss: 0.2306	 accuracy: 0.9233
# loss: 0.2299	 accuracy: 0.9233
# loss: 0.2292	 accuracy: 0.9233
# loss: 0.2286	 accuracy: 0.9233
# loss: 0.2279	 accuracy: 0.9233
# loss: 0.2273	 accuracy: 0.9233
# loss: 0.2267	 accuracy: 0.9233
# loss: 0.2261	 accuracy: 0.9233
# loss: 0.2255	 accuracy: 0.9233
# loss: 0.2249	 accuracy: 0.9233
# loss: 0.2243	 accuracy: 0.9233
# loss: 0.2237	 accuracy: 0.9267
# loss: 0.2232	 accuracy: 0.9267
# loss: 0.2226	 accuracy: 0.9267
# loss: 0.2221	 accuracy: 0.9267
# loss: 0.2215	 accuracy: 0.9267
# loss: 0.221	 accuracy: 0.9267
# loss: 0.2205	 accuracy: 0.9267
# loss: 0.22	 accuracy: 0.9267
# loss: 0.2195	 accuracy: 0.9267
# loss: 0.219	 accuracy: 0.9267
# loss: 0.2185	 accuracy: 0.93
# loss: 0.218	 accuracy: 0.93
# loss: 0.2175	 accuracy: 0.93
# loss: 0.217	 accuracy: 0.93
# loss: 0.2166	 accuracy: 0.93
# loss: 0.2161	 accuracy: 0.93
# loss: 0.2157	 accuracy: 0.93
# loss: 0.2152	 accuracy: 0.9333
# loss: 0.2148	 accuracy: 0.9333
# loss: 0.2143	 accuracy: 0.9333
# loss: 0.2139	 accuracy: 0.9333
# loss: 0.2135	 accuracy: 0.9333
# loss: 0.2131	 accuracy: 0.9333
# loss: 0.2126	 accuracy: 0.9333
# loss: 0.2122	 accuracy: 0.9333
# loss: 0.2118	 accuracy: 0.9333
# loss: 0.2114	 accuracy: 0.9333
# loss: 0.211	 accuracy: 0.9333
# loss: 0.2106	 accuracy: 0.9333
# loss: 0.2102	 accuracy: 0.9333
# loss: 0.2099	 accuracy: 0.9333
# loss: 0.2095	 accuracy: 0.9333
# loss: 0.2091	 accuracy: 0.9333
# loss: 0.2087	 accuracy: 0.9333
# loss: 0.2083	 accuracy: 0.9333
# loss: 0.208	 accuracy: 0.9333
# loss: 0.2076	 accuracy: 0.9333
# loss: 0.2072	 accuracy: 0.9333
# loss: 0.2069	 accuracy: 0.9333
# loss: 0.2065	 accuracy: 0.9333
# loss: 0.2062	 accuracy: 0.9333
# loss: 0.2058	 accuracy: 0.9333
# loss: 0.2055	 accuracy: 0.9333
# loss: 0.2051	 accuracy: 0.9333

# %% [markdown]
# ## 结果展示，无需填写代码

# %%
plt.scatter(C1[:, 0], C1[:, 1], c='b', marker='+')
plt.scatter(C2[:, 0], C2[:, 1], c='g', marker='o')
plt.scatter(C3[:, 0], C3[:, 1], c='r', marker='*')

x = np.arange(0., 10., 0.1)
y = np.arange(0., 10., 0.1)

X, Y = np.meshgrid(x, y)
inp = np.array(list(zip(X.reshape(-1), Y.reshape(-1))), dtype=np.float32)
print(inp.shape)
Z = model(inp)
Z = np.argmax(Z, axis=1)
Z = Z.reshape(X.shape)
plt.contour(X,Y,Z)
plt.show()
# Out:
# (10000, 2)
